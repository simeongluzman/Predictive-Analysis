# %%
import pandas as pd
df = pd.read_csv('internship_assignment.csv')

# %%
user_id_dict = {hashed_id: new_id for new_id, hashed_id in enumerate(df['user_id_hashed'].unique(), start=1)}


df['user_id_hashed'] = df['user_id_hashed'].map(user_id_dict)

df.tail()
# Out:
#        user_id_hashed                   dt       learning_goal  \
# 30474               5  2023-03-07 16:58:45  Java for Beginners
# 30475               5  2023-03-07 16:59:00  Java for Beginners
# 30476               5  2023-03-07 16:59:22  Java for Beginners
# 30477               2  2023-03-07 17:02:44  Java for Beginners
# 30478               2  2023-03-07 17:03:28  Java for Beginners
#
#        selected_track_id  selected_project_id          selected_project  \
# 30474                  8                   53            Bulls and Cows
# 30475                  8                   53            Bulls and Cows
# 30476                  8                   53            Bulls and Cows
# 30477                  8                  113  Simple Chatty Bot (Java)
# 30478                  8                  113  Simple Chatty Bot (Java)
#
#                 topic                   project project_difficulty  step_id  \
# ...

# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# Load the original data
data = df

# Define the columns to be encoded
cat_cols = ['user_id_hashed', , 'learning_goal', 'selected_track_id',
       'selected_project_id', 'selected_project', 'topic', 'project',
       'project_difficulty', 'step_id', 'step', 'step_difficulty', 'action']

label_cols = ['selected_track']

# Uncategorized: 'dt'

# Define the encoding schemes for each column
cat_encoder = OneHotEncoder()
label_encoder = LabelEncoder()

# Define the column transformer
preprocessor = ColumnTransformer(transformers=[
    ('cat', cat_encoder, cat_cols),
    ('label', label_encoder, label_cols)
])

# Fit and transform the data
X_encoded = preprocessor.fit_transform(data)

# Convert the encoded data back to a DataFrame
cols = cat_encoder.get_feature_names(cat_cols).tolist() + label_cols
X_encoded_df = pd.DataFrame(X_encoded.toarray(), columns=cols)

# View the encoded data
print(X_encoded_df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 6
#       3 from sklearn.preprocessing import OneHotEncoder, LabelEncoder
#       5 # Load the original data
# ----> 6 data = pd.read_csv('your_data.csv')
#       8 # Define the columns to be encoded
#       9 cat_cols = ['learning_goal', 'topic']
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
print(df.columns)
# Out:
# Index(['user_id_hashed', 'dt', 'learning_goal', 'selected_track_id',
#        'selected_project_id', 'selected_project', 'topic', 'project',
#        'project_difficulty', 'step_id', 'step', 'step_difficulty', 'action'],
#       dtype='object')

# %%
# Out:
#      user_id_hashed                   dt  learning_goal  selected_track_id  \
# 408               1  2023-03-07 00:00:04  Kotlin Basics                 18
# 498               1  2023-03-07 00:00:31  Kotlin Basics                 18
# 499               1  2023-03-07 00:00:41  Kotlin Basics                 18
# 500               1  2023-03-07 00:00:50  Kotlin Basics                 18
# 501               1  2023-03-07 00:01:07  Kotlin Basics                 18
# 502               1  2023-03-07 00:01:13  Kotlin Basics                 18
# 503               1  2023-03-07 00:01:20  Kotlin Basics                 18
# 504               1  2023-03-07 00:01:30  Kotlin Basics                 18
# 505               1  2023-03-07 00:01:38  Kotlin Basics                 18
# 506               1  2023-03-07 00:01:45  Kotlin Basics                 18
#
#      selected_project_id       selected_project  \
# 408                  106  Sorting Tool (Kotlin)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data


# Count the frequency of each action
action_counts = df['action'].value_counts()

# Create a pie chart
plt.pie(action_counts.values, labels=action_counts.index, autopct='%1.1f%%')
plt.title('User Actions')
plt.axis('equal')
plt.show()
